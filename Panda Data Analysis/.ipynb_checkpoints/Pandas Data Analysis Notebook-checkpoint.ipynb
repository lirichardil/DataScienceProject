# %% [markdown]
# ### Review: Data Sicence Work Flow:

# %% [markdown]
# <div>
# <img src="attachment:c1de8c00-d5d3-42e9-b2d8-ad10f2925784.png" width="500"/>
# </div>

# %% [markdown]
# ### Summary of what we will be coving:

# %% [markdown]
# <div>
# <img src="attachment:ff181034-0e6a-4ae5-a321-9f58d3ef04a2.png" width="200"/>
# </div>

# %% [markdown]
# ### 0. Importing Pandas

# %% [markdown]
# The most common way (and method you should use) is to import pandas as the abbreviation pd (e.g. pandas -> pd).

# %%
import pandas as pd

# %% [markdown]
# ### 1. Datatypes

# %% [markdown]
# #### 1. Series

# %%
series = pd.Series(["BMW","Toyota","Honda"]) # input is a python list

# %%
#to view series
series
# Out:
# 0       BMW
# 1    Toyota
# 2     Honda
# dtype: object

# %% [markdown]
# So in short, Series are 1-dimensional. Almost like a  single column in excel.

# %%
#another example:
colors = pd.Series(['Red','Blue','White'])
colors
# Out:
# 0      Red
# 1     Blue
# 2    White
# dtype: object

# %% [markdown]
# #### 2.Dataframe

# %% [markdown]
# 1. Dataframe is two-dimensions,
# 2. It has more columns, and more common.
# 3. Almost like an Excel Sheet.
# 4. Dataframe takes in python dictionary as the input.

# %%
car_data = pd.DataFrame({"Car make":series, "Colors":colors})
# unlike pd.Series, Dataframe takes in python dictionary 
# the values can be pd.series as well to generate the corresponding 
# data for each column. 

car_data
# Out:
#   Car make Colors
# 0      BMW    Red
# 1   Toyota   Blue
# 2    Honda  White

# %% [markdown]
# ### 2. Importing Data

# %% [markdown]
# A more common way to generate data, instead of create them one by one, we usually import data from different file format, the most common format to import from is .csv

# %%
#import data 
car_sales = pd.read_csv("51 - car-sales.csv")
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors       Price
# 0  Toyota  White         150043      4   $4,000.00
# 1   Honda    Red          87899      4   $5,000.00
# 2  Toyota   Blue          32549      3   $7,000.00
# 3     BMW  Black          11179      5  $22,000.00
# 4  Nissan  White         213095      4   $3,500.00
# 5  Toyota  Green          99213      4   $4,500.00
# 6   Honda   Blue          45698      4   $7,500.00
# 7   Honda   Blue          54738      4   $7,000.00
# 8  Toyota  White          60000      4   $6,250.00
# 9  Nissan  White          31600      4   $9,700.00

# %% [markdown]
# #### Anatomy of a Dataframe

# %% [markdown]
# ![image.png](attachment:a6bc78d5-9c33-4e05-8fa9-f708676edc9b.png)

# %% [markdown]
# Each Column is a key in a dictionary. The columns' names are all the columns in keys in a dictionary.
#
# The value of the key is a series of data.
#
# Row refers to Axis = 0
#
# Column refers to Axis = 1

# %% [markdown]
# ### 3. Exporting Data

# %%
#Exporting a dataframe to csv
car_sales.to_csv("exported-car-sales.csv")

# %%
export_car_sales = pd.read_csv("exported-car-sales.csv")
export_car_sales
# Out:
#    Unnamed: 0    Make Colour  Odometer (KM)  Doors       Price
# 0           0  Toyota  White         150043      4   $4,000.00
# 1           1   Honda    Red          87899      4   $5,000.00
# 2           2  Toyota   Blue          32549      3   $7,000.00
# 3           3     BMW  Black          11179      5  $22,000.00
# 4           4  Nissan  White         213095      4   $3,500.00
# 5           5  Toyota  Green          99213      4   $4,500.00
# 6           6   Honda   Blue          45698      4   $7,500.00
# 7           7   Honda   Blue          54738      4   $7,000.00
# 8           8  Toyota  White          60000      4   $6,250.00
# 9           9  Nissan  White          31600      4   $9,700.00

# %% [markdown]
# We see that in the above data frame, there is an unnamed column. This is because when exporting to CSV.
# it will automatically generate a column for the index. To avoid, we can add in the "index = faluse" option

# %%
car_sales.to_csv("exported-car-sales.csv",index=False)

# %%
export_car_sales = pd.read_csv("exported-car-sales.csv")
export_car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors       Price
# 0  Toyota  White         150043      4   $4,000.00
# 1   Honda    Red          87899      4   $5,000.00
# 2  Toyota   Blue          32549      3   $7,000.00
# 3     BMW  Black          11179      5  $22,000.00
# 4  Nissan  White         213095      4   $3,500.00
# 5  Toyota  Green          99213      4   $4,500.00
# 6   Honda   Blue          45698      4   $7,500.00
# 7   Honda   Blue          54738      4   $7,000.00
# 8  Toyota  White          60000      4   $6,250.00
# 9  Nissan  White          31600      4   $9,700.00

# %% [markdown]
# ### 4. Describe data

# %% [markdown]
# One of the first things you'll want to do after you import some data into a pandas DataFrame is to start exploring it.
#
# pandas has many built in functions which allow you to quickly get information about a DataFrame.
#
# Let's explore some using the car_sales DataFrame.

# %%
car_sales.dtypes # tell us the data type of each column(key)
# Out:
# Make             object
# Colour           object
# Odometer (KM)     int64
# Doors             int64
# Price            object
# dtype: object

# %%
car_sales.columns # tell us the column name
# Out:
# Index(['Make', 'Colour', 'Odometer (KM)', 'Doors', 'Price'], dtype='object')

# %%
car_columns = car_sales.columns # saving columns info to car_columns

# %%
car_sales.index
# Out:
# RangeIndex(start=0, stop=10, step=1)

# %%
car_sales.info
# Out:
# <bound method DataFrame.info of      Make Colour  Odometer (KM)  Doors       Price
# 0  Toyota  White         150043      4   $4,000.00
# 1   Honda    Red          87899      4   $5,000.00
# 2  Toyota   Blue          32549      3   $7,000.00
# 3     BMW  Black          11179      5  $22,000.00
# 4  Nissan  White         213095      4   $3,500.00
# 5  Toyota  Green          99213      4   $4,500.00
# 6   Honda   Blue          45698      4   $7,500.00
# 7   Honda   Blue          54738      4   $7,000.00
# 8  Toyota  White          60000      4   $6,250.00
# 9  Nissan  White          31600      4   $9,700.00>

# %%
car_sales.describe() # notice that there is a () at the end meaning that this is a function
# Out:
#        Odometer (KM)      Doors
# count      10.000000  10.000000
# mean    78601.400000   4.000000
# std     61983.471735   0.471405
# min     11179.000000   3.000000
# 25%     35836.250000   4.000000
# 50%     57369.000000   4.000000
# 75%     96384.500000   4.000000
# max    213095.000000   5.000000

# %% [markdown]
# We notice that Price is not included. This is because Price is not a int64, but rather an object.
# And describe only works for (int)

# %%
car_sales.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10 entries, 0 to 9
# Data columns (total 5 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Make           10 non-null     object
#  1   Colour         10 non-null     object
#  2   Odometer (KM)  10 non-null     int64
#  3   Doors          10 non-null     int64
#  4   Price          10 non-null     object
# dtypes: int64(2), object(3)
# memory usage: 532.0+ bytes

# %%
car_sales.mean(numeric_only=True)
# Out:
# Odometer (KM)    78601.4
# Doors                4.0
# dtype: float64

# %%
car_sales["Doors"].sum() # select a single column in a pd.
# Out:
# 40

# %%
len(car_sales) # give you the number of row
# Out:
# 10

# %% [markdown]
# ### 5 Viewing and selecting data

# %% [markdown]
# #### 5.0 Summary

# %% [markdown]
# Some common methods for viewing and selecting data in a pandas DataFrame include:
#
#     DataFrame.head(n=5) - Displays the first n rows of a DataFrame (e.g. car_sales.head() will show the first 5 rows of the car_sales DataFrame).
#
#     DataFrame.tail(n=5) - Displays the last n rows of a DataFrame.
#
#     DataFrame.loc[] - Accesses a group of rows and columns by labels or a boolean array.
#
#     DataFrame.iloc[] - Accesses a group of rows and columns by integer indices (e.g. car_sales.iloc[0] shows all the columns from index 0.
#
#     DataFrame.columns - Lists the column labels of the DataFrame.
#
#     DataFrame['A'] - Selects the column named 'A' from the DataFrame.
#
#     DataFrame[DataFrame['A'] > 5] - Boolean indexing filters rows based on column values meeting a condition (e.g. all rows from column 'A' greater than 5.
#
#     DataFrame.plot() - Creates a line plot of a DataFrame's columns (e.g. plot Make vs. Odometer (KM) columns with car_sales[["Make", "Odometer (KM)"]].plot();).
#
#     DataFrame.hist() - Generates histograms for columns in a DataFrame.
#
#
#     pandas.crosstab() - Computes a cross-tabulation of two or more factors.

# %% [markdown]
# #### 5.1 Select Row

# %% [markdown]
# ##### 5.1.1 head and tail function

# %%
car_sales.head() # head is just the first five rows of the data frame
# Out:
#      Make Colour  Odometer (KM)  Doors       Price
# 0  Toyota  White         150043      4   $4,000.00
# 1   Honda    Red          87899      4   $5,000.00
# 2  Toyota   Blue          32549      3   $7,000.00
# 3     BMW  Black          11179      5  $22,000.00
# 4  Nissan  White         213095      4   $3,500.00

# %%
car_sales.head(7)
# Out:
#      Make Colour  Odometer (KM)  Doors       Price
# 0  Toyota  White         150043      4   $4,000.00
# 1   Honda    Red          87899      4   $5,000.00
# 2  Toyota   Blue          32549      3   $7,000.00
# 3     BMW  Black          11179      5  $22,000.00
# 4  Nissan  White         213095      4   $3,500.00
# 5  Toyota  Green          99213      4   $4,500.00
# 6   Honda   Blue          45698      4   $7,500.00

# %%
car_sales.tail(7)
# Out:
#      Make Colour  Odometer (KM)  Doors       Price
# 3     BMW  Black          11179      5  $22,000.00
# 4  Nissan  White         213095      4   $3,500.00
# 5  Toyota  Green          99213      4   $4,500.00
# 6   Honda   Blue          45698      4   $7,500.00
# 7   Honda   Blue          54738      4   $7,000.00
# 8  Toyota  White          60000      4   $6,250.00
# 9  Nissan  White          31600      4   $9,700.00

# %% [markdown]
# ##### 5.1.2 .loc and .iloc (location and position)

# %%
animals = pd.Series(["cat","dog","bird","panda","snake"])

# %%
animals
# Out:
# 0      cat
# 1      dog
# 2     bird
# 3    panda
# 4    snake
# dtype: object

# %% [markdown]
# by default, the index starts from 0, however, we can modify the index by adding index = option

# %%
animals = pd.Series(["cat","dog","bird","panda","snake"],index=[0,3,9,9,3])

animals
# Out:
# 0      cat
# 3      dog
# 9     bird
# 9    panda
# 3    snake
# dtype: object

# %%
animals.loc[3]
# Out:
# 3      dog
# 3    snake
# dtype: object

# %%
animals.loc[9]
# Out:
# 9     bird
# 9    panda
# dtype: object

# %%
car_sales.loc[3]
# Out:
# Make                    BMW
# Colour                Black
# Odometer (KM)         11179
# Doors                     5
# Price            $22,000.00
# Name: 3, dtype: object

# %%
#iloc
animals.iloc[3] # absolute index, not the
# Out:
# 'panda'

# %% [markdown]
# with the function iloc, we can do slicing on the data

# %%
animals.iloc[3:] # from the third terms till the end
# Out:
# 9    panda
# 3    snake
# dtype: object

# %%
animals.iloc[2::2] # from the second terms till the end, increment 2
# Out:
# 9     bird
# 3    snake
# dtype: object

# %% [markdown]
# #### 5.2 Select Column

# %%
#before, we learn about selecting column using brack + string

# %%
car_sales["Make"]
# Out:
# 0    Toyota
# 1     Honda
# 2    Toyota
# 3       BMW
# 4    Nissan
# 5    Toyota
# 6     Honda
# 7     Honda
# 8    Toyota
# 9    Nissan
# Name: Make, dtype: object

# %%
#another way to select colomn
car_sales.Make
# Out:
# 0    Toyota
# 1     Honda
# 2    Toyota
# 3       BMW
# 4    Nissan
# 5    Toyota
# 6     Honda
# 7     Honda
# 8    Toyota
# 9    Nissan
# Name: Make, dtype: object

# %%
#Boolean selection
car_sales[car_sales["Make"] == "Toyota"]
# Out:
#      Make Colour  Odometer (KM)  Doors      Price
# 0  Toyota  White         150043      4  $4,000.00
# 2  Toyota   Blue          32549      3  $7,000.00
# 5  Toyota  Green          99213      4  $4,500.00
# 8  Toyota  White          60000      4  $6,250.00

# %%
car_sales[car_sales["Odometer (KM)"] >= 100000 ]
# Out:
#      Make Colour  Odometer (KM)  Doors      Price
# 0  Toyota  White         150043      4  $4,000.00
# 4  Nissan  White         213095      4  $3,500.00

# %% [markdown]
# #### 5.4 Other useful function

# %% [markdown]
# 1. Using crosstab to cross two columns. Basically turning one column into row, one column stays in column

# %%
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors    Price
# 0  Toyota  White         150043      4   400000
# 1   Honda    Red          87899      4   500000
# 2  Toyota   Blue          32549      3   700000
# 3     BMW  Black          11179      5  2200000
# 4  Nissan  White         213095      4   350000
# 5  Toyota  Green          99213      4   450000
# 6   Honda   Blue          45698      4   750000
# 7   Honda   Blue          54738      4   700000
# 8  Toyota  White          60000      4   625000
# 9  Nissan  White          31600      4   970000

# %%
pd.crosstab(car_sales["Make"],car_sales["Doors"])
# Out:
# Doors   3  4  5
# Make
# BMW     0  0  1
# Honda   0  3  0
# Nissan  0  2  0
# Toyota  1  3  0

# %% [markdown]
# 2. using group-by to group the data frame, and giving you the mean value of the data frame.

# %%
car_sales.groupby(["Make"]).mean(numeric_only=True)
# Out:
#         Odometer (KM)  Doors
# Make
# BMW      11179.000000   5.00
# Honda    62778.333333   4.00
# Nissan  122347.500000   4.00
# Toyota   85451.250000   3.75

# %%
car_sales.groupby(["Colour"]).mean(numeric_only=True)
# Out:
#         Odometer (KM)     Doors
# Colour
# Black    11179.000000  5.000000
# Blue     44328.333333  3.666667
# Green    99213.000000  4.000000
# Red      87899.000000  4.000000
# White   113684.500000  4.000000

# %% [markdown]
# #### 5.5 Visualization

# %% [markdown]
# pandas even allows for quick plotting of columns so you can see your data visualling. To plot, you'll have to import matplotlib. If your plots aren't showing, try running the two lines of code below.
#
# %matplotlib inline
#
# is a special command which tells Jupyter to show your plots. Commands with % at the front are called magic commands.

# %%
# Import matplotlib and tell Jupyter to show plots
import matplotlib.pyplot as plt
# %matplotlib inline 
#plot the plot in the notebook so that you can see it.

# %%
car_sales["Odometer (KM)"].plot(); # tip: the ";" on the end prevents matplotlib from outputing the plot class

# %%
car_sales["Odometer (KM)"].hist();

# %%
# if we want to transfer an object to int. for example, from ($1000) to (100)
# we can do some research and find out that the way to convert $ to obj is as folow:

car_sales["Price"] = car_sales['Price'].str.replace("[$,.]", "", regex=True).astype(int)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[117], line 4
#       1 # if we want to transfer an object to int. for example, from ($1000) to (100)
#       2 # we can do some research and find out that the way to convert $ to obj is as folow:
# ----> 4 car_sales["Price"] = car_sales['Price'].str.replace("[$,.]", "", regex=True).astype(int)
#
# File ~/Desktop/sample_project/env/lib/python3.12/site-packages/pandas/core/generic.py:6296, in NDFrame.__getattr__(self, name)
#    6289 if (
#    6290     name not in self._internal_names_set
#    6291     and name not in self._metadata
#    6292     and name not in self._accessors
#    6293     and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    6294 ):
#    6295     return self[name]
# -> 6296 return object.__getattribute__(self, name)
#
# ...

# %%
car_sales['Price'] = car_sales['Price'].divide(100)

# %%
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors  Price
# 0  Toyota  White         150043      4   40.0
# 1   Honda    Red          87899      4   50.0
# 2  Toyota   Blue          32549      3   70.0
# 3     BMW  Black          11179      5  220.0
# 4  Nissan  White         213095      4   35.0
# 5  Toyota  Green          99213      4   45.0
# 6   Honda   Blue          45698      4   75.0
# 7   Honda   Blue          54738      4   70.0
# 8  Toyota  White          60000      4   62.5
# 9  Nissan  White          31600      4   97.0

# %%
car_sales['Price'].plot();

# %% [markdown]
# #### 5.6 Manipulating Data

# %% [markdown]
# ##### 1. lowering the str

# %%
car_sales["Make"].str.lower()
# Out:
# 0    toyota
# 1     honda
# 2    toyota
# 3       bmw
# 4    nissan
# 5    toyota
# 6     honda
# 7     honda
# 8    toyota
# 9    nissan
# Name: Make, dtype: object

# %%
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors  Price
# 0  Toyota  White         150043      4   40.0
# 1   Honda    Red          87899      4   50.0
# 2  Toyota   Blue          32549      3   70.0
# 3     BMW  Black          11179      5  220.0
# 4  Nissan  White         213095      4   35.0
# 5  Toyota  Green          99213      4   45.0
# 6   Honda   Blue          45698      4   75.0
# 7   Honda   Blue          54738      4   70.0
# 8  Toyota  White          60000      4   62.5
# 9  Nissan  White          31600      4   97.0

# %% [markdown]
# Although we changed the str to lowercase, we did not reassign it/replace it.
# To have this take effect, we need to re-assign it.
#
# Or we can use the "in place" argument in some of the function.

# %%
car_sales["Make"] = car_sales["Make"].str.lower()

# %%
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors  Price
# 0  toyota  White         150043      4   40.0
# 1   honda    Red          87899      4   50.0
# 2  toyota   Blue          32549      3   70.0
# 3     bmw  Black          11179      5  220.0
# 4  nissan  White         213095      4   35.0
# 5  toyota  Green          99213      4   45.0
# 6   honda   Blue          45698      4   75.0
# 7   honda   Blue          54738      4   70.0
# 8  toyota  White          60000      4   62.5
# 9  nissan  White          31600      4   97.0

# %% [markdown]
# ##### 2. Missing data

# %% [markdown]
# In real world, we often see missing data on a data frame

# %% [markdown]
# ![image.png](attachment:4967b957-da2b-4dfa-a038-f388aa0af5e9.png)

# %%
car_sales_missdata = pd.read_csv("56 - car-sales-missing-data.csv")

# %%
car_sales_missdata
# Out:
#      Make Colour  Odometer  Doors    Price
# 0  Toyota  White  150043.0    4.0   $4,000
# 1   Honda    Red   87899.0    4.0   $5,000
# 2  Toyota   Blue       NaN    3.0   $7,000
# 3     BMW  Black   11179.0    5.0  $22,000
# 4  Nissan  White  213095.0    4.0   $3,500
# 5  Toyota  Green       NaN    4.0   $4,500
# 6   Honda    NaN       NaN    4.0   $7,500
# 7   Honda   Blue       NaN    4.0      NaN
# 8  Toyota  White   60000.0    NaN      NaN
# 9     NaN  White   31600.0    4.0   $9,700

# %% [markdown]
# 3. Filling in data.
#    To fill NaN, we can use a function call "fillna"

# %%
car_sales_missdata["Odometer"].fillna(car_sales_missdata["Odometer"].mean())
# Out:
# 0    150043.000000
# 1     87899.000000
# 2     92302.666667
# 3     11179.000000
# 4    213095.000000
# 5     92302.666667
# 6     92302.666667
# 7     92302.666667
# 8     60000.000000
# 9     31600.000000
# Name: Odometer, dtype: float64

# %% [markdown]
# Noted that because we didn't re-assign it, the dataframe itself didn't change.

# %%
car_sales_missdata
# Out:
#      Make Colour  Odometer  Doors    Price
# 0  Toyota  White  150043.0    4.0   $4,000
# 1   Honda    Red   87899.0    4.0   $5,000
# 2  Toyota   Blue       NaN    3.0   $7,000
# 3     BMW  Black   11179.0    5.0  $22,000
# 4  Nissan  White  213095.0    4.0   $3,500
# 5  Toyota  Green       NaN    4.0   $4,500
# 6   Honda    NaN       NaN    4.0   $7,500
# 7   Honda   Blue       NaN    4.0      NaN
# 8  Toyota  White   60000.0    NaN      NaN
# 9     NaN  White   31600.0    4.0   $9,700

# %%
car_sales_missdata["Odometer"].fillna(car_sales_missdata["Odometer"].mean(),inplace=True)
# Out:
# /var/folders/kw/wpzr0vt13d5fdyz240v227km0000gn/T/ipykernel_54421/512166939.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   car_sales_missdata["Odometer"].fillna(car_sales_missdata["Odometer"].mean(),inplace=True)

# %%
# now we see that the NaN odometer values has been updated. 
car_sales_missdata
# Out:
#      Make Colour       Odometer  Doors    Price
# 0  Toyota  White  150043.000000    4.0   $4,000
# 1   Honda    Red   87899.000000    4.0   $5,000
# 2  Toyota   Blue   92302.666667    3.0   $7,000
# 3     BMW  Black   11179.000000    5.0  $22,000
# 4  Nissan  White  213095.000000    4.0   $3,500
# 5  Toyota  Green   92302.666667    4.0   $4,500
# 6   Honda    NaN   92302.666667    4.0   $7,500
# 7   Honda   Blue   92302.666667    4.0      NaN
# 8  Toyota  White   60000.000000    NaN      NaN
# 9     NaN  White   31600.000000    4.0   $9,700

# %% [markdown]
# 4. Dropping NaN data. Or if we just want to neglect all the NaN row, we can use the dropna function.

# %%
car_sales_missdata.dropna(inplace=True)

# %%
car_sales_missdata
# Out:
#      Make Colour       Odometer  Doors    Price
# 0  Toyota  White  150043.000000    4.0   $4,000
# 1   Honda    Red   87899.000000    4.0   $5,000
# 2  Toyota   Blue   92302.666667    3.0   $7,000
# 3     BMW  Black   11179.000000    5.0  $22,000
# 4  Nissan  White  213095.000000    4.0   $3,500
# 5  Toyota  Green   92302.666667    4.0   $4,500

# %% [markdown]
# to re-access the dropped value, we will have to re-import the csv

# %%
car_sales_missdata = pd.read_csv("56 - car-sales-missing-data.csv")

# %%
car_sales_missdata_drop = car_sales_missdata.dropna()

# %%
car_sales_missdata_drop
# Out:
#      Make Colour  Odometer  Doors    Price
# 0  Toyota  White  150043.0    4.0   $4,000
# 1   Honda    Red   87899.0    4.0   $5,000
# 3     BMW  Black   11179.0    5.0  $22,000
# 4  Nissan  White  213095.0    4.0   $3,500

# %%
car_sales_missdata
# Out:
#      Make Colour  Odometer  Doors    Price
# 0  Toyota  White  150043.0    4.0   $4,000
# 1   Honda    Red   87899.0    4.0   $5,000
# 2  Toyota   Blue       NaN    3.0   $7,000
# 3     BMW  Black   11179.0    5.0  $22,000
# 4  Nissan  White  213095.0    4.0   $3,500
# 5  Toyota  Green       NaN    4.0   $4,500
# 6   Honda    NaN       NaN    4.0   $7,500
# 7   Honda   Blue       NaN    4.0      NaN
# 8  Toyota  White   60000.0    NaN      NaN
# 9     NaN  White   31600.0    4.0   $9,700

# %% [markdown]
# ##### 3. Creating Column Data

# %%
#create column from panda series
#1. create the series
seats_column = pd.Series([5,5,5,5,5])

#2. add new column
car_sales_missdata["Seats"] = seats_column

# %%
car_sales_missdata
# Out:
#      Make Colour  Odometer  Doors    Price  Seats
# 0  Toyota  White  150043.0    4.0   $4,000    5.0
# 1   Honda    Red   87899.0    4.0   $5,000    5.0
# 2  Toyota   Blue       NaN    3.0   $7,000    5.0
# 3     BMW  Black   11179.0    5.0  $22,000    5.0
# 4  Nissan  White  213095.0    4.0   $3,500    5.0
# 5  Toyota  Green       NaN    4.0   $4,500    NaN
# 6   Honda    NaN       NaN    4.0   $7,500    NaN
# 7   Honda   Blue       NaN    4.0      NaN    NaN
# 8  Toyota  White   60000.0    NaN      NaN    NaN
# 9     NaN  White   31600.0    4.0   $9,700    NaN

# %%
# 3. create a column from python list
fuel_economy = [7.5,9.2,5.0,9.6,8.7]
car_sales["Fuel per 100kM"] = fuel_economy
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[173], line 3
#       1 # create a column from python list
#       2 fuel_economy = [7.5,9.2,5.0,9.6,8.7]
# ----> 3 car_sales["Fuel per 100kM"] = fuel_economy
#
# File ~/Desktop/sample_project/env/lib/python3.12/site-packages/pandas/core/frame.py:4299, in DataFrame.__setitem__(self, key, value)
#    4296     self._setitem_array([key], value)
#    4297 else:
#    4298     # set column
# -> 4299     self._set_item(key, value)
#
# File ~/Desktop/sample_project/env/lib/python3.12/site-packages/pandas/core/frame.py:4512, in DataFrame._set_item(self, key, value)
#    4502 def _set_item(self, key, value) -> None:
#    4503     """
#    4504     Add series to DataFrame in specified column.
#    4505
#    (...)
#    4510     ensure homogeneity.
#    4511     """
# -> 4512     value, refs = self._sanitize_column(value)
# ...

# %% [markdown]
# Notice that if we create a column from a list, the index of the list has to match the row.

# %%
fuel_economy = [7.5,9.2,5.0,9.6,8.7,5.6,7.5,6.5,2.3,12.2]
car_sales["Fuel per 100kM"] = fuel_economy
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors  Price  Fuel per 100kM
# 0  toyota  White         150043      4   40.0             7.5
# 1   honda    Red          87899      4   50.0             9.2
# 2  toyota   Blue          32549      3   70.0             5.0
# 3     bmw  Black          11179      5  220.0             9.6
# 4  nissan  White         213095      4   35.0             8.7
# 5  toyota  Green          99213      4   45.0             5.6
# 6   honda   Blue          45698      4   75.0             7.5
# 7   honda   Blue          54738      4   70.0             6.5
# 8  toyota  White          60000      4   62.5             2.3
# 9  nissan  White          31600      4   97.0            12.2

# %%
# 4. create a column from a column.
# if we want to find out how many liters of fuel the cars have consumed. 
# which devide ["Fuel per 100KM" ] and times it by the Odometer value

car_sales["Total fuel used"] = car_sales["Odometer (KM)"]/100 * car_sales["Fuel per 100kM"]
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors  Price  Fuel per 100kM  Total fuel used
# 0  toyota  White         150043      4   40.0             7.5        11253.225
# 1   honda    Red          87899      4   50.0             9.2         8086.708
# 2  toyota   Blue          32549      3   70.0             5.0         1627.450
# 3     bmw  Black          11179      5  220.0             9.6         1073.184
# 4  nissan  White         213095      4   35.0             8.7        18539.265
# 5  toyota  Green          99213      4   45.0             5.6         5555.928
# 6   honda   Blue          45698      4   75.0             7.5         3427.350
# 7   honda   Blue          54738      4   70.0             6.5         3557.970
# 8  toyota  White          60000      4   62.5             2.3         1380.000
# 9  nissan  White          31600      4   97.0            12.2         3855.200

# %%
# 5. create column from single value

car_sales["Number of Wheel"] = 4
car_sales

car_sales["Safety passed?"] = True
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors  Price  Fuel per 100kM  \
# 0  toyota  White         150043      4   40.0             7.5
# 1   honda    Red          87899      4   50.0             9.2
# 2  toyota   Blue          32549      3   70.0             5.0
# 3     bmw  Black          11179      5  220.0             9.6
# 4  nissan  White         213095      4   35.0             8.7
# 5  toyota  Green          99213      4   45.0             5.6
# 6   honda   Blue          45698      4   75.0             7.5
# 7   honda   Blue          54738      4   70.0             6.5
# 8  toyota  White          60000      4   62.5             2.3
# 9  nissan  White          31600      4   97.0            12.2
#
#    Total fuel used  Number of Wheel  Safety passed?
# 0        11253.225                4            True
# 1         8086.708                4            True
# 2         1627.450                4            True
# 3         1073.184                4            True
# ...

# %% [markdown]
# ##### 4. Removing Column Data

# %%
car_sales.drop("Total fuel used",axis=1,inplace=True)

# %%
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors  Price  Fuel per 100kM  \
# 0  toyota  White         150043      4   40.0             7.5
# 1   honda    Red          87899      4   50.0             9.2
# 2  toyota   Blue          32549      3   70.0             5.0
# 3     bmw  Black          11179      5  220.0             9.6
# 4  nissan  White         213095      4   35.0             8.7
# 5  toyota  Green          99213      4   45.0             5.6
# 6   honda   Blue          45698      4   75.0             7.5
# 7   honda   Blue          54738      4   70.0             6.5
# 8  toyota  White          60000      4   62.5             2.3
# 9  nissan  White          31600      4   97.0            12.2
#
#    Number of Wheel  Safety passed?
# 0                4            True
# 1                4            True
# 2                4            True
# 3                4            True
# 4                4            True
# 5                4            True
# ...

# %% [markdown]
# ##### 5. Shuffle data - mixing up index

# %%
car_sales.sample(frac=0.5) # taking 50% (0.5) of the dataset as sample and shuffle them
# Out:
#      Make Colour  Odometer (KM)  Doors  Price  Fuel per 100kM  \
# 1   honda    Red          87899      4   50.0             9.2
# 2  toyota   Blue          32549      3   70.0             5.0
# 0  toyota  White         150043      4   40.0             7.5
# 5  toyota  Green          99213      4   45.0             5.6
# 3     bmw  Black          11179      5  220.0             9.6
#
#    Number of Wheel  Safety passed?
# 1                4            True
# 2                4            True
# 0                4            True
# 5                4            True
# 3                4            True

# %%
car_sales_shuffled = car_sales.sample(frac=1) # taking 100% (1) of the dataset as sample and shuffle them

# %%
car_sales_shuffled
# Out:
#      Make Colour  Odometer (KM)  Doors  Price  Fuel per 100kM  \
# 7   honda   Blue          54738      4   70.0             6.5
# 9  nissan  White          31600      4   97.0            12.2
# 3     bmw  Black          11179      5  220.0             9.6
# 1   honda    Red          87899      4   50.0             9.2
# 6   honda   Blue          45698      4   75.0             7.5
# 4  nissan  White         213095      4   35.0             8.7
# 0  toyota  White         150043      4   40.0             7.5
# 5  toyota  Green          99213      4   45.0             5.6
# 8  toyota  White          60000      4   62.5             2.3
# 2  toyota   Blue          32549      3   70.0             5.0
#
#    Number of Wheel  Safety passed?
# 7                4            True
# 9                4            True
# 3                4            True
# 1                4            True
# 6                4            True
# 4                4            True
# ...

# %%
# when there are many of data, it takes very long to shuffle, we can select 20% of the data to shuffle.
car_sales_shuffled.sample(frac=0.2)
# Out:
#      Make Colour  Odometer (KM)  Doors  Price  Fuel per 100kM  \
# 9  nissan  White          31600      4   97.0            12.2
# 2  toyota   Blue          32549      3   70.0             5.0
#
#    Number of Wheel  Safety passed?
# 9                4            True
# 2                4            True

# %%
#get them back to order


car_sales
# Out:
#    level_0  index    Make Colour  Odometer (KM)  Doors  Price  Fuel per 100kM  \
# 0        0      1   honda    Red          87899      4   50.0             9.2
# 1        1      9  nissan  White          31600      4   97.0            12.2
# 2        2      6   honda   Blue          45698      4   75.0             7.5
# 3        3      5  toyota  Green          99213      4   45.0             5.6
# 4        4      0  toyota  White         150043      4   40.0             7.5
# 5        5      4  nissan  White         213095      4   35.0             8.7
# 6        6      2  toyota   Blue          32549      3   70.0             5.0
# 7        7      7   honda   Blue          54738      4   70.0             6.5
# 8        8      8  toyota  White          60000      4   62.5             2.3
# 9        9      3     bmw  Black          11179      5  220.0             9.6
#
#    Number of Wheel  Safety passed?
# 0                4            True
# 1                4            True
# ...

# %%
car_sales.drop(["level_0","index"],axis=1,inplace=True)

# %%
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors  Price  Fuel per 100kM  \
# 0   honda    Red      54936.875      4   50.0             9.2
# 1  nissan  White      19750.000      4   97.0            12.2
# 2   honda   Blue      28561.250      4   75.0             7.5
# 3  toyota  Green      62008.125      4   45.0             5.6
# 4  toyota  White      93776.875      4   40.0             7.5
# 5  nissan  White     133184.375      4   35.0             8.7
# 6  toyota   Blue      20343.125      3   70.0             5.0
# 7   honda   Blue      34211.250      4   70.0             6.5
# 8  toyota  White      37500.000      4   62.5             2.3
# 9     bmw  Black       6986.875      5  220.0             9.6
#
#    Number of Wheel  Safety passed?
# 0                4            True
# 1                4            True
# 2                4            True
# 3                4            True
# 4                4            True
# 5                4            True
# ...

# %% [markdown]
# ##### 6. Applying a function to a entire column

# %%
# let say we want to convert KM to mile in the odometer. 
car_sales['Odometer (KM)'] = car_sales['Odometer (KM)'].apply(lambda x: x/1.6)

# %%
car_sales.rename(columns= {'Odometer (KM)':'Odometer (Mile)'},inplace=True)

car_sales
# Out:
#      Make Colour  Odometer (Mile)  Doors  Price  Fuel per 100kM  \
# 0   honda    Red     34335.546875      4   50.0             9.2
# 1  nissan  White     12343.750000      4   97.0            12.2
# 2   honda   Blue     17850.781250      4   75.0             7.5
# 3  toyota  Green     38755.078125      4   45.0             5.6
# 4  toyota  White     58610.546875      4   40.0             7.5
# 5  nissan  White     83240.234375      4   35.0             8.7
# 6  toyota   Blue     12714.453125      3   70.0             5.0
# 7   honda   Blue     21382.031250      4   70.0             6.5
# 8  toyota  White     23437.500000      4   62.5             2.3
# 9     bmw  Black      4366.796875      5  220.0             9.6
#
#    Number of Wheel  Safety passed?
# 0                4            True
# 1                4            True
# 2                4            True
# 3                4            True
# 4                4            True
# 5                4            True
# ...
